# %% [markdown]
# # Import Data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Melbourne_housing_FULL.csv")
df
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis   3/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
# Feature selection

columns= ["Suburb", "Rooms", "Type", "Price", "Distance", "Bedroom2", "Bathroom", "Car", "Landsize", "BuildingArea", 
          'YearBuilt', 'CouncilArea', 'Lattitude',
       'Longtitude', 'Regionname', 'Propertycount']
df_filtered = df[columns]
df_filtered
# Out:
#            Suburb  Rooms Type      Price  Distance  Bedroom2  Bathroom  Car  \
# 0      Abbotsford      2    h        NaN       2.5       2.0       1.0  1.0
# 1      Abbotsford      2    h  1480000.0       2.5       2.0       1.0  1.0
# 2      Abbotsford      2    h  1035000.0       2.5       2.0       1.0  0.0
# 3      Abbotsford      3    u        NaN       2.5       3.0       2.0  1.0
# 4      Abbotsford      3    h  1465000.0       2.5       3.0       2.0  0.0
# ...           ...    ...  ...        ...       ...       ...       ...  ...
# 34852  Yarraville      4    h  1480000.0       6.3       4.0       1.0  3.0
# 34853  Yarraville      2    h   888000.0       6.3       2.0       2.0  1.0
# 34854  Yarraville      2    t   705000.0       6.3       2.0       1.0  2.0
# 34855  Yarraville      3    h  1140000.0       6.3       NaN       NaN  NaN
# 34856  Yarraville      2    h  1020000.0       6.3       2.0       1.0  0.0
#
# ...

# %%
# Type filtering
df_filtered = df_filtered[df_filtered['Type']=='h']
df_filtered
# Out:
#            Suburb  Rooms Type      Price  Distance  Bedroom2  Bathroom  Car  \
# 0      Abbotsford      2    h        NaN       2.5       2.0       1.0  1.0
# 1      Abbotsford      2    h  1480000.0       2.5       2.0       1.0  1.0
# 2      Abbotsford      2    h  1035000.0       2.5       2.0       1.0  0.0
# 4      Abbotsford      3    h  1465000.0       2.5       3.0       2.0  0.0
# 5      Abbotsford      3    h   850000.0       2.5       3.0       2.0  1.0
# ...           ...    ...  ...        ...       ...       ...       ...  ...
# 34851  Yarraville      3    h  1101000.0       6.3       3.0       1.0  NaN
# 34852  Yarraville      4    h  1480000.0       6.3       4.0       1.0  3.0
# 34853  Yarraville      2    h   888000.0       6.3       2.0       2.0  1.0
# 34855  Yarraville      3    h  1140000.0       6.3       NaN       NaN  NaN
# 34856  Yarraville      2    h  1020000.0       6.3       2.0       1.0  0.0
#
# ...

# %%
# Missing Value
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23980 entries, 0 to 34856
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         23980 non-null  object
#  1   Rooms          23980 non-null  int64
#  2   Type           23980 non-null  object
#  3   Price          18472 non-null  float64
#  4   Distance       23979 non-null  float64
#  5   Bedroom2       20422 non-null  float64
#  6   Bathroom       20416 non-null  float64
#  7   Car            19932 non-null  float64
#  8   Landsize       17694 non-null  float64
#  9   BuildingArea   10413 non-null  float64
#  10  YearBuilt      11453 non-null  float64
#  11  CouncilArea    23978 non-null  object
#  12  Lattitude      20540 non-null  float64
#  13  Longtitude     20540 non-null  float64
#  14  Regionname     23978 non-null  object
#  15  Propertycount  23978 non-null  float64
# dtypes: float64(11), int64(1), object(4)
# memory usage: 3.1+ MB

# %%
df_filtered.dropna(how='any', inplace=True)
df_filtered
# Out:
# C:\Users\AVISHEK DAS\AppData\Local\Temp\ipykernel_7540\1491313293.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.dropna(how='any', inplace=True)
#              Suburb  Rooms Type      Price  Distance  Bedroom2  Bathroom  Car  \
# 2        Abbotsford      2    h  1035000.0       2.5       2.0       1.0  0.0
# 4        Abbotsford      3    h  1465000.0       2.5       3.0       2.0  0.0
# 6        Abbotsford      4    h  1600000.0       2.5       3.0       1.0  2.0
# 11       Abbotsford      3    h  1876000.0       2.5       4.0       2.0  0.0
# 14       Abbotsford      2    h  1636000.0       2.5       2.0       1.0  2.0
# ...             ...    ...  ...        ...       ...       ...       ...  ...
# 34837  Williamstown      5    h  2020000.0       6.8       5.0       3.0  2.0
# ...

# %%
df_filtered.drop(columns=['Type'], inplace=True)
df_filtered
# Out:
# C:\Users\AVISHEK DAS\AppData\Local\Temp\ipykernel_7540\739251707.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.drop(columns=['Type'], inplace=True)
#              Suburb  Rooms      Price  Distance  Bedroom2  Bathroom  Car  \
# 2        Abbotsford      2  1035000.0       2.5       2.0       1.0  0.0
# 4        Abbotsford      3  1465000.0       2.5       3.0       2.0  0.0
# 6        Abbotsford      4  1600000.0       2.5       3.0       1.0  2.0
# 11       Abbotsford      3  1876000.0       2.5       4.0       2.0  0.0
# 14       Abbotsford      2  1636000.0       2.5       2.0       1.0  2.0
# ...             ...    ...        ...       ...       ...       ...  ...
# 34837  Williamstown      5  2020000.0       6.8       5.0       3.0  2.0
# ...

# %%
df_filtered["Suburb"].value_counts()
# Out:
# Suburb
# Reservoir           126
# Brunswick           110
# Coburg              103
# Preston             102
# Bentleigh East       96
#                    ...
# Beaconsfield          1
# Whittlesea            1
# Springvale South      1
# Cranbourne North      1
# Research              1
# Name: count, Length: 313, dtype: int64

# %%
Reservoid = [1,0,0,0,0,0,0,] # one-hot encoding

# %%
df_filtered.columns
# Out:
# Index(['Suburb', 'Rooms', 'Price', 'Distance', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df_filtered = df_filtered[['Rooms', 'Price', 'Distance', 'Bedroom2', 'Bathroom', 'Car',
       'Landsize', 'BuildingArea', 'YearBuilt', 'Lattitude',
       'Longtitude',  "Propertycount"]]
df_filtered
# Out:
#        Rooms      Price  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 2          2  1035000.0       2.5       2.0       1.0  0.0     156.0
# 4          3  1465000.0       2.5       3.0       2.0  0.0     134.0
# 6          4  1600000.0       2.5       3.0       1.0  2.0     120.0
# 11         3  1876000.0       2.5       4.0       2.0  0.0     245.0
# 14         2  1636000.0       2.5       2.0       1.0  2.0     256.0
# ...      ...        ...       ...       ...       ...  ...       ...
# 34837      5  2020000.0       6.8       5.0       3.0  2.0     450.0
# 34847      3   500000.0      25.5       3.0       2.0  2.0     383.0
# 34849      3   570000.0      25.5       3.0       2.0  2.0     404.0
# 34853      2   888000.0       6.3       2.0       2.0  1.0      98.0
# 34856      2  1020000.0       6.3       2.0       1.0  0.0     250.0
#
#        BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# 2              79.0     1900.0  -37.80790   144.99340         4019.0
# ...

# %%
df_filtered.describe()
# Out:
#              Rooms         Price     Distance     Bedroom2     Bathroom  \
# count  6625.000000  6.625000e+03  6625.000000  6625.000000  6625.000000
# mean      3.388679  1.230542e+06    12.163608     3.364981     1.733283
# std       0.845754  7.123283e+05     7.160510     0.854220     0.747955
# min       1.000000  1.310000e+05     1.300000     0.000000     1.000000
# 25%       3.000000  7.455000e+05     7.200000     3.000000     1.000000
# 50%       3.000000  1.045000e+06    11.200000     3.000000     2.000000
# 75%       4.000000  1.500000e+06    14.700000     4.000000     2.000000
# max      12.000000  9.000000e+06    47.400000    12.000000     9.000000
#
#                Car      Landsize  BuildingArea    YearBuilt    Lattitude  \
# count  6625.000000   6625.000000   6625.000000  6625.000000  6625.000000
# mean      1.837132    565.395472    166.833746  1958.742189   -37.799571
# std       1.043387    881.958076     89.853481    37.593008     0.096595
# ...

# %%
X = df_filtered[['Rooms', 'Distance', 'Bedroom2', 'Bathroom', 'Car',
       'Landsize', 'BuildingArea', 'YearBuilt', 'Lattitude',
       'Longtitude',  "Propertycount"]]
y = df_filtered['Price']

# %%
df_filtered.corr()
# Out:
#                   Rooms     Price  Distance  Bedroom2  Bathroom       Car  \
# Rooms          1.000000  0.344834  0.156106  0.948929  0.610654  0.307661
# Price          0.344834  1.000000 -0.388513  0.326072  0.412747  0.108232
# Distance       0.156106 -0.388513  1.000000  0.167274  0.062712  0.208194
# Bedroom2       0.948929  0.326072  0.167274  1.000000  0.615502  0.312476
# Bathroom       0.610654  0.412747  0.062712  0.615502  1.000000  0.252487
# Car            0.307661  0.108232  0.208194  0.312476  0.252487  1.000000
# Landsize       0.138964  0.050883  0.221302  0.138513  0.088879  0.157753
# BuildingArea   0.529312  0.431248  0.031337  0.511954  0.525996  0.240162
# YearBuilt      0.199742 -0.268079  0.468526  0.211515  0.264165  0.241947
# Lattitude     -0.037803 -0.277334 -0.059826 -0.032615 -0.060571 -0.001260
# Longtitude     0.106593  0.229369  0.146987  0.105126  0.124165  0.033535
# Propertycount -0.026775 -0.036579  0.051389 -0.024884 -0.030151  0.000005
#
# ...

# %%
df_filtered.plot(x='Distance', y='Price', kind='scatter')
# Out:
# <Axes: xlabel='Distance', ylabel='Price'>

# %%
df_filtered.plot(x='BuildingArea', y='Price', kind='scatter')
# Out:
# <Axes: xlabel='BuildingArea', ylabel='Price'>

# %% [markdown]
# # Train-Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
X_train
# Out:
#        Rooms  Distance  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 21607      3      14.7       3.0       2.0  1.0     251.0         194.0
# 10062      3      11.2       3.0       2.0  2.0     808.0         159.0
# 29587      3      16.0       3.0       2.0  2.0     728.0         137.0
# 32712      3      31.7       3.0       1.0  2.0     580.0          96.0
# 8687       5      11.2       3.0       2.0  2.0     548.0         285.0
# ...      ...       ...       ...       ...  ...       ...           ...
# 18396      3       4.3       3.0       1.0  0.0     199.0         126.0
# 26432      3       2.7       3.0       2.0  0.0     343.0         153.0
# 26619      3      23.2       3.0       1.0  2.0     721.0          99.0
# 27676      4      20.6       4.0       2.0  2.0     538.0         179.0
# 3928       4       7.7       3.0       3.0  0.0     235.0         211.0
#
#        YearBuilt  Lattitude  Longtitude  Propertycount
# ...

# %%
X_train.shape
# Out:
# (4637, 11)

# %%
X_test.shape
# Out:
# (1988, 11)

# %% [markdown]
# # Scaling of Data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.45819181,  0.35311469, -0.42284731, ..., -1.13915571,
#         -2.33351277,  2.0326828 ],
#        [-0.45819181, -0.12987983, -0.42284731, ..., -0.3414983 ,
#          0.91732532, -0.42986266],
#        [-0.45819181,  0.53251265, -0.42284731, ..., -1.55462381,
#          0.31545369, -0.58232018],
#        ...,
#        [-0.45819181,  1.52610137, -0.42284731, ..., -0.54819885,
#          2.11939269, -0.52805174],
#        [ 0.730748  ,  1.16730545,  0.75336323, ...,  2.3042687 ,
#         -0.59097214,  1.88183493],
#        [ 0.730748  , -0.61287435, -0.42284731, ..., -0.81174205,
#         -0.06687686,  0.38232434]])

# %% [markdown]
# # Model Training

# %%
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor(max_depth=5)

# %%
model.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %% [markdown]
# # Asses Model

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
y_train_pred = model.predict(X_train_scaled)

# %%
y_test_pred = model.predict(X_test_scaled)

# %%
train_mse = mean_squared_error(y_train, y_train_pred)
print("Training MSE:", train_mse)
# Out:
# Training MSE: 175603736890.2622

# %%
test_mse = mean_squared_error(y_test, y_test_pred)
print("Test MSE:", test_mse)
# Out:
# Test MSE: 188822160761.4411

# %%
train_mse/1.230542e+06
# Out:
# 142704.38302005312

# %%
train_mae = mean_absolute_error(y_train, y_train_pred)
print("Training MAE:", train_mae)
# Out:
# Training MAE: 265104.9367143661

# %%
test_mae = mean_absolute_error(y_test, y_test_pred)
print("Test MAE:", test_mae)
# Out:
# Test MAE: 286618.5690868651

# %%
train_mae/1.230542e+06
# Out:
# 0.21543753623554993

# %%
test_mae/1.230542e+06
# Out:
# 0.23292059034707074
